# %%
import pandas as pd
from matplotlib import pyplot as plt

import sys
sys.path.append('../utils/')
from data import *

# %%
df_download_info = pd.read_csv("../data/download_descriptions.csv")
df_download_info
# Out:
#              movie   age        group  has-en-sub  \
# 0    Black Panther  2018    White Man           0
# 1    Black Panther  2018    White Man           0
# 2    Black Panther  2018    White Man           0
# 3    Black Panther  2018    Black Man           0
# 4    Black Panther  2018    Black Man           0
# ..             ...   ...          ...         ...
# 632          Logan  2017  White Woman           0
# 633          Logan  2017    Black Man           0
# 634          Logan  2017    Black Man           0
# 635          Logan  2017    Black Man           0
# 636          Logan  2017    Black Man           0
#
#                                                    url
# 0    https://www.youtube.com/watch?v=A_yiL6YB7LE&ab...
# 1    https://www.youtube.com/watch?v=7Usr96nwjqI&ab...
# 2    https://www.youtube.com/watch?v=BQtPELpog1o&ab...
# 3    https://www.youtube.com/watch?v=Wc0pK98d65Q&ab...
# 4    https://www.youtube.com/watch?v=UVwBpHknNzY&ab...
# ...

# %%
df = get_movies_dataset()
df
# Out:
#              movie   age        group  has-en-sub  \
# 0    Black Panther  2018    White Man           0
# 1    Black Panther  2018    White Man           0
# 2    Black Panther  2018    White Man           0
# 3    Black Panther  2018    Black Man           0
# 4    Black Panther  2018    Black Man           0
# ..             ...   ...          ...         ...
# 630          Logan  2017  White Woman           0
# 631          Logan  2017    Black Man           0
# 632          Logan  2017    Black Man           0
# 633          Logan  2017    Black Man           0
# 634          Logan  2017    Black Man           0
#
#                                                    url           id  \
# 0    https://www.youtube.com/watch?v=A_yiL6YB7LE&ab...  A_yiL6YB7LE
# 1    https://www.youtube.com/watch?v=7Usr96nwjqI&ab...  7Usr96nwjqI
# 2    https://www.youtube.com/watch?v=BQtPELpog1o&ab...  BQtPELpog1o
# 3    https://www.youtube.com/watch?v=Wc0pK98d65Q&ab...  Wc0pK98d65Q
# ...

# %%
data = df.groupby(['group','age']).count()[['movie']].reset_index()
# for group
for group in data.group.unique():
    plt.plot(data[data.group == group].age, data[data.group == group].movie, label=group)
plt.legend()

# %%
sns.displot(df, x="age", hue="group", kind="kde")

# %%
df[(df['age']>1960)&(df['age']<1980)]
# Out:
#              movie   age      group  has-en-sub  \
# 121  The Godfather  1972  White Man           0
# 122  The Godfather  1972  White Man           0
# 123  The Godfather  1972  White Man           0
# 124  The Godfather  1972  White Man           0
# 125  The Godfather  1972  White Man           0
# 126  The Godfather  1972  Black Man           0
# 127  The Godfather  1972  Black Man           0
# 128  The Godfather  1972  Black Man           0
# 129  The Godfather  1972  Black Man           0
#
#                                                    url           id  \
# 121  https://www.youtube.com/watch?v=_ksFX-4Io_c&ab...  _ksFX-4Io_c
# 122  https://www.youtube.com/watch?v=46hGRtL03o8&ab...  46hGRtL03o8
# 123  https://www.youtube.com/watch?v=eKdDJ2Leuik&ab...  eKdDJ2Leuik
# 124  https://www.youtube.com/watch?v=HWA4hluFYBM&ab...  HWA4hluFYBM
# 125  https://www.youtube.com/watch?v=JntAuFXkWMs&ab...  JntAuFXkWMs
# 126  https://www.youtube.com/watch?v=alCCz1cgZz0&ab...  alCCz1cgZz0
# ...

# %%
movies = [movie for movie in df.groupby('movie').count()['age'].sort_values()[::-1].index]
plt.figure(figsize=(25,15))
plt.rcParams.update({'font.size': 22})

plt.xticks(rotation=90,)
for group in data.group.unique():
    l = [
        data[(data.movie==movie)&(data.group==group) ]['age'] 
        if len(data[(data.movie==movie)&(data.group==group) ]['age']) > 0
        else 0
        for movie in movies
    ]
    plt.plot(movies, l,label=group)
plt.legend()
# Out:
# /home/luiznery/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

movies_data = df.groupby(['group','age','movie']).count()[['id']].reset_index()
movies_data
# Out:
#            group   age                       movie  id
# 0      Black Man  1940      The Philadelphia Story   1
# 1      Black Man  1942                  Casablanca   1
# 2      Black Man  1972               The Godfather   4
# 3      Black Man  2014                       Selma   5
# 4      Black Man  2015                  Inside Out   6
# ..           ...   ...                         ...  ..
# 148  White Woman  2019                The Farewell   3
# 149  White Woman  2019                The Irishman   4
# 150  White Woman  2019                   Toy Story   1
# 151  White Woman  2019                          Us   5
# 152  White Woman  2020  Portrait of a Lady on Fire   4
#
# [153 rows x 4 columns]

# %%
movies = movies_data.pivot("age", "movie", "id")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(movies, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-c549d7d0ee2e> in <module>
# ----> 1 movies = movies_data.pivot("age", "movie", "id")
#       2
#       3 # Draw a heatmap with the numeric values in each cell
#       4 f, ax = plt.subplots(figsize=(9, 6))
#       5 sns.heatmap(movies, annot=True, fmt="d", linewidths=.5, ax=ax)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    6672         from pandas.core.reshape.pivot import pivot
#    6673
# -> 6674         return pivot(self, index=index, columns=columns, values=values)
#    6675
#    6676     _shared_docs[
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     475         else:
#     476             indexed = data._constructor_sliced(data[values]._values, index=index)
# ...

# %%
df
# Out:
#              movie   age        group  has-en-sub  \
# 0    Black Panther  2018    White Man           0
# 1    Black Panther  2018    White Man           0
# 2    Black Panther  2018    White Man           0
# 3    Black Panther  2018    Black Man           0
# 4    Black Panther  2018    Black Man           0
# ..             ...   ...          ...         ...
# 630          Logan  2017  White Woman           0
# 631          Logan  2017    Black Man           0
# 632          Logan  2017    Black Man           0
# 633          Logan  2017    Black Man           0
# 634          Logan  2017    Black Man           0
#
#                                                    url           id  \
# 0    https://www.youtube.com/watch?v=A_yiL6YB7LE&ab...  A_yiL6YB7LE
# 1    https://www.youtube.com/watch?v=7Usr96nwjqI&ab...  7Usr96nwjqI
# 2    https://www.youtube.com/watch?v=BQtPELpog1o&ab...  BQtPELpog1o
# 3    https://www.youtube.com/watch?v=Wc0pK98d65Q&ab...  Wc0pK98d65Q
# ...

# %%
df.groupby('movie').count()['age'].sort_values()[::-1].index
# Out:
# Index(['The Shape of Water', 'Inside Out', 'Booksmart', 'The Farewell',
#        'Wonder Woman', 'Spider Man: Into the Spider Verse', 'Selma',
#        'A Quiet Place', 'Roma', 'Moonlight', 'Eighth Grade', 'Dunkirk',
#        'The Favourite', 'A Star Is Born', 'Mad Max: Fury Road', 'The Irishman',
#        'Logan', 'Thor: Ragnarok', 'BlacKkKlansman', 'Coco', 'Us',
#        'Portrait of a Lady on Fire', 'Star Wars: The Last Jedi', 'Spotlight',
#        'Lady Bird', 'Rebecca', 'The Cabinet of Dr. Caligari', 'Arrival',
#        'Black Panther', 'Rear Window', 'Singin' in the Rain', 'Get Out',
#        'The Godfather', 'The Philadelphia Story', 'Double Indemenity',
#        'The Third Man', 'Avengers: Endgame', 'Seven Samurai', 'All About Eve',
#        'Knives Out', 'A Night at the Opera', 'It Happened One Night',
#        'Mission Impossible - Fallout', 'Parasite', 'Toy Story', 'Modern Times',
#        'Casablanca', 'Citizen Kane', 'La Grande Illusion', 'The Wizard of Oz'],
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-a70455b55ef2> in <module>
# ----> 1 data.sort
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'
