# %%
import pandas as pd
import sys
import glob
import os

from tqdm import tqdm

sys.path.append("../../../../utils")
from absolute_path_builder import AbsolutePathBuilder

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
# DATASET = "youtube"
# DATASET = "coraal_vs_buckeye"
DATASET = "twitter"

if DATASET == "twitter":
    pvalue = 0.05
    n_largest = 50
else:
    pvalue = 0.01
    n_largest = 25

input_path = AbsolutePathBuilder.get_path(
    f"06_{DATASET}_regression",
    filepaths="../../../../config/filepaths.yaml"
)

# %%
df = None
for SCORE_MODEL in tqdm(
    [
        "perspective",
        "flair",
        "textblob",
        "vader",
        "detoxify_original",
        "detoxify_unbiased",
    ]
):
    df_model = pd.read_csv(os.path.join(input_path, f"{SCORE_MODEL}_score_coefs.csv"))
    
    # Select the most relevant columns according to the p-value and the coefficient
    df_model = (
        df_model[df_model.pvalue < pvalue]
        .sort_values(
            "coef",
            key=lambda item: abs(item),
            ascending=False
        ).iloc[:n_largest]
        [["column", "coef"]]
    )

    df_model = df_model.rename(columns={"coef": f"{SCORE_MODEL}"})
    
    if df is None:
        df = df_model
    else:
        df = df.merge(df_model, on="column", how="outer")
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 133.83it/s]

# %%
df_result = df.dropna(thresh=4).reset_index(drop=True)

# %%
df_result
# Out:
#              column  perspective   flair  textblob   vader  detoxify_original  \
# 0        LIWC_SWEAR       0.8567     NaN       NaN     NaN             0.9492
# 1       LIWC_SEXUAL       0.4657 -1.3448   -0.3354     NaN             0.5942
# 2     LIWC_NETSPEAK      -0.4496 -2.6379       NaN     NaN            -0.8121
# 3     LIWC_INFORMAL       0.4386  2.5228       NaN     NaN             0.7988
# 4             POS_X      -0.3857     NaN    0.5655 -0.1636            -0.4255
# 5   AAE_TERMS_COUNT       0.2238     NaN       NaN  0.0934             0.1779
# 6       LIWC_NEGATE       0.2075 -0.8331       NaN     NaN                NaN
# 7           POS_DET       0.1623     NaN       NaN     NaN             0.3369
# 8       LIWC_ASSENT      -0.1599     NaN       NaN     NaN            -0.2614
# 9         LIWC_MALE      -0.1505     NaN   -0.3237     NaN            -0.1968
# 10             race       0.0508     NaN       NaN     NaN             0.1262
# 11      LIWC_FILLER          NaN -2.1683       NaN     NaN            -0.6053
#
#     detoxify_unbiased
# 0              1.2792
# 1              0.5609
# 2             -0.9239
# 3              0.9460
# 4             -0.3066
# 5                 NaN
# 6              0.1855
# 7              0.3268
# 8             -0.1985
# 9             -0.1910
# 10             0.0762
# 11            -0.6377

# %%
df_result.column.values
# Out:
# array(['LIWC_SWEAR', 'LIWC_SEXUAL', 'LIWC_NETSPEAK', 'LIWC_INFORMAL',
#        'POS_X', 'AAE_TERMS_COUNT', 'LIWC_NEGATE', 'POS_DET',
#        'LIWC_ASSENT', 'LIWC_MALE', 'race', 'LIWC_FILLER'], dtype=object)
