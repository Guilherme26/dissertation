# %%
import pandas as pd
import sys
import glob
import os

from tqdm import tqdm

sys.path.append("../../../../utils")
from absolute_path_builder import AbsolutePathBuilder

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
DATASET = "youtube"
# DATASET = "coraal_vs_buckeye"
# DATASET = "twitter"

if DATASET == "twitter":
    pvalue = 0.05
    n_largest = 50
else:
    pvalue = 0.01
    n_largest = 25

input_path = AbsolutePathBuilder.get_path(
    f"06_{DATASET}_regression",
    filepaths="../../../../config/filepaths.yaml"
)

# %%
df = None
for SCORE_MODEL in tqdm(
    [
        "perspective",
        "flair",
        "textblob",
        "vader",
        "detoxify_original",
        "detoxify_unbiased",
    ]
):
    df_model = pd.read_csv(os.path.join(input_path, f"{SCORE_MODEL}_score_coefs.csv"))
    
    # Select the most relevant columns according to the p-value and the coefficient
    df_model = (
        df_model[df_model.pvalue < pvalue]
        .sort_values(
            "coef",
            key=lambda item: abs(item),
            ascending=False
        ).iloc[:n_largest]
        [["column", "coef"]]
    )

    df_model = df_model.rename(columns={"coef": f"{SCORE_MODEL}"})
    
    if df is None:
        df = df_model
    else:
        df = df.merge(df_model, on="column", how="outer")
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 152.53it/s]

# %%
df_result = df.dropna(thresh=4).reset_index(drop=True)

# %%
df_result
# Out:
#               column  perspective   flair  textblob   vader  \
# 0         LIWC_SWEAR       1.4529     NaN       NaN  0.2137
# 1         LIWC_DEATH       1.0922 -3.1559    0.3438  1.8787
# 2        LIWC_SEXUAL       0.7733 -2.1333   -0.4023  0.0712
# 3          LIWC_BODY       0.6038 -2.4150   -1.6790  0.0782
# 4        LIWC_NEGEMO       0.5267 -3.3423   -1.2651  0.9376
# 5         LIWC_ANGER       0.3485     NaN    0.2931  0.3694
# 6        LIWC_FILLER      -0.2525 -1.4227       NaN     NaN
# 7    AAE_TERMS_COUNT       0.2488     NaN       NaN  0.0617
# 8        LIWC_ASSENT      -0.2394 -0.7194    0.2790 -0.0938
# 9        LIWC_NONFLU      -0.2303     NaN       NaN -0.0686
# 10     LIWC_INFORMAL       0.2236     NaN       NaN  0.0775
# 11          LIWC_SAD      -0.1992     NaN    0.4311  0.2289
# 12       LIWC_INGEST       0.1893 -1.5451   -1.1896     NaN
# 13        LIWC_RELIG       0.1764 -0.9880       NaN     NaN
# 14     LIWC_NETSPEAK      -0.1568     NaN       NaN     NaN
# 15       LIWC_SOCIAL       0.1381     NaN       NaN     NaN
# 16         LIWC_WORK      -0.1141     NaN       NaN     NaN
# 17         LIWC_FEEL       0.1124 -1.1777   -0.3244  0.0791
# 18       LIWC_HEALTH       0.1099 -2.0063   -1.8130  0.1785
# 19    LIWC_FOCUSPAST      -0.0815 -1.5012       NaN     NaN
# 20      LIWC_DISCREP       0.0798     NaN    0.2604     NaN
# 21  LIWC_AFFILIATION      -0.0753  1.2576    0.7533     NaN
# 22       LIWC_NEGATE          NaN -3.7329   -0.2661  0.4872
# 23         LIWC_RISK          NaN -1.2727    0.4176  0.7053
# 24       LIWC_ACHIEV          NaN  0.9477    1.3981     NaN
# 25       LIWC_POSEMO          NaN  0.9255    1.6945 -0.3710
# 26      LIWC_LEISURE          NaN  0.7763       NaN -0.0692
# 27          LIWC_ANX          NaN     NaN    0.4744  0.1719
# 28        LIWC_QUANT          NaN     NaN    0.4075 -0.0952
# 29      LIWC_COGPROC          NaN     NaN       NaN -0.0623
#
#     detoxify_original  detoxify_unbiased
# 0              2.1020             2.1819
# 1              1.5901             1.3711
# 2              0.7051             0.8716
# 3              0.5397             0.4376
# 4              0.2902             0.3222
# 5              0.2662             0.4039
# 6             -0.3458            -0.2979
# 7                 NaN             0.1334
# 8             -0.3079            -0.2824
# 9             -0.3301            -0.2987
# 10             0.3146             0.2887
# 11            -0.1175            -0.1392
# 12                NaN                NaN
# 13             0.2261                NaN
# 14            -0.2241            -0.2578
# 15             0.1342             0.0701
# 16            -0.0878            -0.0494
# 17                NaN                NaN
# 18             0.1295                NaN
# 19            -0.1150            -0.0778
# 20                NaN             0.0710
# 21            -0.0970                NaN
# 22                NaN                NaN
# 23                NaN                NaN
# 24            -0.0507                NaN
# 25                NaN                NaN
# 26            -0.0667            -0.0529
# 27            -0.1528            -0.1357
# 28                NaN            -0.0511
# 29            -0.0934            -0.0685

# %%
df_result.column.values
# Out:
# array(['LIWC_SWEAR', 'LIWC_DEATH', 'LIWC_SEXUAL', 'LIWC_BODY',
#        'LIWC_NEGEMO', 'LIWC_ANGER', 'LIWC_FILLER', 'AAE_TERMS_COUNT',
#        'LIWC_ASSENT', 'LIWC_NONFLU', 'LIWC_INFORMAL', 'LIWC_SAD',
#        'LIWC_INGEST', 'LIWC_RELIG', 'LIWC_NETSPEAK', 'LIWC_SOCIAL',
#        'LIWC_WORK', 'LIWC_FEEL', 'LIWC_HEALTH', 'LIWC_FOCUSPAST',
#        'LIWC_DISCREP', 'LIWC_AFFILIATION', 'LIWC_NEGATE', 'LIWC_RISK',
#        'LIWC_ACHIEV', 'LIWC_POSEMO', 'LIWC_LEISURE', 'LIWC_ANX',
#        'LIWC_QUANT', 'LIWC_COGPROC'], dtype=object)
