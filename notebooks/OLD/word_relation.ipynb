# %%
import pandas as pd
import os

import sys
sys.path.append('../utils/')
from data import *
from analisys import *

# %%
movies = get_movies_dataset()
movies = movies.set_index('id')
movies['score'] = total_score
movies = movies.reset_index()

# %% [markdown]
# ----

# %%
get_word_relations('ass', movies[movies['group']=="White Man"].text_clean)
# Out:
# ({'kicking': 3,
#   'my': 3,
#   'your': 3,
#   'great': 2,
#   'serious': 1,
#   '': 2,
#   'his': 3,
#   'Schreiber': 1,
#   'weird': 1,
#   'some': 2,
#   'her': 3,
#   'shopped': 1,
#   'loud': 1,
#   'funny': 1,
#   'difficult': 1,
#   'kick': 1,
#   "Cartman's": 1,
#   'of': 1,
#   "everyone's": 1},
#  {'and': 8,
#   'off': 2,
#   'but': 1,
#   'in': 2,
#   'instead': 1,
#   'not': 1,
#   'keepin': 1,
#   'kingpin': 1,
#   'makeup': 1,
#   "let's": 1,
#   'when': 1,
#   'I': 1,
#   'it': 2,
#   'toy': 1,
#   'movie': 1,
#   'a': 1,
#   'handed': 1,
#   'telling': 1,
#   'admittedly': 1,
#   'hope': 1,
#   'he': 1,
#   'this': 1})

# %%
get_word_relations('ass', movies[movies['group']=="Black Woman"].text_clean)
# Out:
# ({'his': 2, 'an': 1, 'dumb': 1, 'kick': 1},
#  {'out': 1, 'was': 1, 'but': 1, 'doorknobs': 1, 'and': 1})

# %% [markdown]
# ----

# %%
get_word_relations('black', movies[movies['group']=="White Man"].text_clean)
# Out:
# ({'saw': 1,
#   'me': 2,
#   'the': 20,
#   'a': 21,
#   'being': 1,
#   'and': 4,
#   'enjoy': 2,
#   'have': 1,
#   'film': 4,
#   'panther': 1,
#   'movie': 2,
#   'wear': 1,
#   'psycho': 1,
#   'was': 1,
#   'looking': 2,
#   'to': 1,
#   'or': 1,
#   'seen': 1,
#   'of': 8,
#   'perfect': 1,
#   'is': 3,
#   '': 2,
#   'so': 4,
#   'real': 1,
#   'all': 3,
#   'enjoyed': 1,
#   'get': 2,
#   "shi'ite": 1,
#   'again': 1,
#   'matte': 1,
#   'give': 2,
#   'about': 4,
#   'part': 1,
#   'giving': 1,
#   'anyway': 1,
#   'first': 1,
#   'though': 1,
#   'both': 1,
#   'only': 2,
#   'in': 6,
#   'see': 2,
#   'like': 4,
#   'think': 1,
#   'that': 3,
#   'where': 1,
#   'found': 1,
#   'thought': 1,
#   "he's": 2,
#   'her': 2,
#   'on': 1,
#   'those': 1,
#   'shiny': 1,
#   '1930s': 1,
#   'plays': 1,
#   'as': 1,
#   'name': 1,
#   'inviting': 1,
#   'town': 1,
#   'because': 1,
#   'with': 2,
#   'old': 1,
#   'called': 1,
#   '20-something': 1,
#   'young': 1,
# ...

# %%
get_word_relations('black', movies[movies['group']=="Black Woman"].text_clean)
# Out:
# ({'has': 1,
#   'says': 1,
#   'a': 22,
#   'different': 1,
#   'have': 1,
#   'of': 8,
#   'what': 1,
#   'and': 1,
#   'free': 1,
#   'on': 2,
#   'as': 1,
#   'know': 2,
#   'for': 3,
#   'like': 4,
#   'another': 1,
#   'not': 1,
#   'predominantly': 2,
#   'positive': 1,
#   'first': 2,
#   'beautiful': 1,
#   'african-american': 1,
#   'reviewing': 1,
#   'screamed': 1,
#   'me': 1,
#   'specifically': 1,
#   'murderous': 1,
#   'all': 4,
#   'the': 18,
#   'loved': 1,
#   'other': 2,
#   'to': 3,
#   'every': 1,
#   'why': 2,
#   'with': 1,
#   "it's": 1,
#   'then': 1,
#   'imply': 1,
#   'this': 2,
#   'that': 2,
#   'Chris': 1,
#   'said': 1,
#   'is': 3,
#   "he's": 1,
#   'out': 1,
#   'young': 7,
#   'his': 1,
#   'dark': 1,
#   'crackhead': 1,
#   'poor': 3,
#   'moonlight': 1,
#   'in': 2,
#   "that's": 1,
#   'dark-skinned': 1,
#   'are': 1,
#   'play': 1,
#   'being': 1,
#   'stereotypical': 1,
#   'by': 2,
#   'need': 1,
#   'gay': 2,
#   'be': 2,
#   "you're": 1,
# ...
