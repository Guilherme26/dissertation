# %% [markdown]
# # Imports, styles, etc

# %%
import numpy as np
import pandas as pd
from liwc import Liwc
from matplotlib import pyplot as plt
import seaborn as sns
import json
from tqdm import tqdm
import scipy

import scipy.stats as stats

import sys
sys.path.append('../utils/')
from data import *
from liwc import *
from analisys import *

# %%
plt.rcParams['axes.labelsize']  = 10 # fontes no tamanho usado no template
plt.rcParams['axes.titlesize']  = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['font.family'] = 'serif'
# plt.rcParams['text.usetex'] = True
plt.rcParams['lines.linewidth'] = 2

# %%
plt.style.use('tableau-colorblind10') # use um estilo colorblind!
plt.ion()

# %% [markdown]
# ---

# %% [markdown]
# # Reading and processing data

# %%
def liwc_sentence_parse(s,liwc):
    return liwc.parse(s.split(' '))

def get_key_counts(counter,key):
    if key in counter:
        return counter[key]
    else:
        return 0

LIWC_FILEPATH = '../data/LIWC2015_English_Flat.dic'
liwc = Liwc(LIWC_FILEPATH)

df = get_movies_dataset()
df['liwc_count'] = df['text_clean'].apply(liwc_sentence_parse, args=(liwc,))
df['bad_words_count'] = df['tags_count'].apply(get_key_counts,args=(' __ ',))
df = df[df.bad_words_count==0]
df = df.drop(columns = ['tags_count','bad_words_count'])

# %%
scores = pd.DataFrame()
for file in os.listdir('../data/03_scored/without_inputation/normal_toxicity/'):
    tmp = pd.read_csv('../data/03_scored/without_inputation/normal_toxicity/'+file)
    tmp['id']=file
    scores = scores.append(tmp, ignore_index=True)
scores['len'] = scores.text.str.split(' ').str.len()

total_score = (scores.groupby('id')['score'].sum()/scores.groupby('id')['len'].sum()).sort_values()[::-1]

# %%
df = df.set_index('id')
df['score'] = total_score
df = df.reset_index()
df = df[df.score.notna()]

# %%
d = get_movies_dataset()
d['bad_words_count'] = d['tags_count'].apply(get_key_counts,args=(' __ ',))

# %%
#subtitles without any imputation
d[d.bad_words_count==0].groupby('group').count()
# Out:
#              movie  age  has-en-sub  url   id  text  text_clean  tags_count  \
# group
# Black Man       82   82          82   82   82    82          82          82
# Black Woman     42   42          42   42   42    42          42          42
# White Man      267  267         267  267  267   267         267         267
# White Woman    162  162         162  162  162   162         162         162
#
#              bad_words_count
# group
# Black Man                 82
# Black Woman               42
# White Man                267
# White Woman              162

# %% [markdown]
# ---

# %% [markdown]
# # Processing data with LIWC

# %%
#LIWC data

LIWC_FILEPATH = '../data/LIWC2015_English_Flat.dic'
liwc = Liwc(LIWC_FILEPATH)

liwc_df = pd.DataFrame().from_records(df['liwc_count'],index=df['id'])
liwc_df = liwc_df.fillna(0)

#normalizing 
liwc_df_norm = (liwc_df[liwc.categories.values()].T * ( 1 / liwc_df[liwc.categories.values()].sum(axis=1) )).T

liwc_df_norm.reset_index(inplace=True)
liwc_df_norm['group'] = df['group']
liwc_df_norm['age'] = df['age']

# %%
#calculating mean rank for each liwc category in order to apply kruskall-wallis test

liwc_df_rank = liwc_df_norm.copy()
for col in liwc.categories.values():
    liwc_df_rank[col] = liwc_df_rank[col].rank()

# %% [markdown]
# ---

# %% [markdown]
# ## Kruscal-Wallis Test

# %%
experiments = []
old_experiments = []

for feature in liwc.categories.values():
    
    result = stats.kruskal(
        liwc_df_norm[liwc_df_norm.group=='White Man'][feature],
        liwc_df_norm[liwc_df_norm.group=='White Woman'][feature],
        liwc_df_norm[liwc_df_norm.group=='Black Man'][feature],
        liwc_df_norm[liwc_df_norm.group=='Black Woman'][feature],
    )
    experiments.append({
        'feature': feature,
        'statistic': result[0],
        'pvalue': result[1]
    })
experiments = pd.DataFrame(experiments)

# %% [markdown]
# ---

# %%
liwc_df_rank.groupby('group').median()[list(interesting_var)].T['Black Man'].sort_values()
# Out:
# quant        176.0
# adj          179.0
# conj         191.0
# article      210.0
# adverb       215.0
# number       239.0
# relativ      273.0
# space        286.0
# assent       303.0
# focuspast    344.0
# netspeak     355.0
# pronoun      373.0
# informal     382.0
# verb         394.0
# you          404.0
# Name: Black Man, dtype: float64

# %%
liwc_df_rank.groupby('group').median()[list(interesting_var)].T['Black Woman'].sort_values()
# Out:
# quant        117.5
# relativ      145.0
# space        149.0
# adj          177.5
# number       190.5
# article      217.5
# adverb       237.0
# conj         246.0
# you          323.5
# pronoun      344.0
# focuspast    345.0
# verb         365.5
# netspeak     374.0
# assent       388.0
# informal     390.5
# Name: Black Woman, dtype: float64

# %%
liwc_df_rank.groupby('group').median()[list(interesting_var)].T['White Man'].sort_values()
# Out:
# verb         220.5
# assent       220.5
# focuspast    222.5
# informal     238.5
# pronoun      241.5
# you          246.0
# adverb       259.0
# conj         262.5
# netspeak     263.5
# quant        306.5
# adj          307.5
# relativ      324.5
# article      326.5
# number       329.0
# space        334.0
# Name: White Man, dtype: float64

# %%
liwc_df_rank.groupby('group').median()[list(interesting_var)].T['White Woman'].sort_values()
# Out:
# number       210.5
# space        212.0
# netspeak     213.0
# article      220.5
# relativ      233.0
# pronoun      252.5
# informal     261.0
# you          261.0
# verb         278.5
# adj          290.0
# focuspast    303.5
# quant        308.5
# assent       316.0
# conj         351.0
# adverb       371.5
# Name: White Woman, dtype: float64

# %%
print(liwc_df_norm.groupby('group').mean()[list(interesting_var)].T.to_latex(float_format=lambda x: '%.3f' % x))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# group &  Black Man &  Black Woman &  White Man &  White Woman \\
# \midrule
# quant     &      0.008 &        0.007 &      0.010 &        0.009 \\
# informal  &      0.005 &        0.005 &      0.003 &        0.004 \\
# space     &      0.021 &        0.019 &      0.022 &        0.020 \\
# verb      &      0.062 &        0.062 &      0.058 &        0.060 \\
# netspeak  &      0.001 &        0.001 &      0.001 &        0.001 \\
# relativ   &      0.040 &        0.036 &      0.041 &        0.039 \\
# article   &      0.024 &        0.023 &      0.027 &        0.024 \\
# conj      &      0.026 &        0.027 &      0.027 &        0.029 \\
# number    &      0.004 &        0.003 &      0.004 &        0.003 \\
# assent    &      0.001 &        0.002 &      0.001 &        0.001 \\
# focuspast &      0.014 &        0.014 &      0.012 &        0.014 \\
# adj       &      0.015 &        0.014 &      0.017 &        0.016 \\
# you       &      0.009 &        0.007 &      0.006 &        0.007 \\
# pronoun   &      0.055 &        0.055 &      0.052 &        0.052 \\
# adverb    &      0.024 &        0.024 &      0.025 &        0.027 \\
# \bottomrule
# \end{tabular}

# %%
liwc_df_rank
# Out:
#               id  function  pronoun  ppron      i     we    you  shehe   they  \
# 0    A_yiL6YB7LE     257.0    401.0  407.0  169.0  368.0  406.0  424.0  306.0
# 1    BQtPELpog1o      91.0    219.0  404.0  363.0  275.0  504.0  322.0   97.0
# 2    Wc0pK98d65Q     121.0    499.0  534.0  150.0  511.0  435.0  514.0  485.0
# 3    id882pdRz40     210.0    265.0  392.0  201.0  495.0  192.0  457.0  299.0
# 4    h_Qo0arHl5Q     217.0    286.0  261.0  301.0  320.0  383.0  114.0  489.0
# ..           ...       ...      ...    ...    ...    ...    ...    ...    ...
# 547  D-Ue15pL_Lk      30.0    374.5  371.0  291.0  310.0  146.0  509.0   79.0
# 548  csbRjP3GyhQ     456.0    367.0  368.0  457.0  445.0  156.0  406.0  226.0
# 549  LZqhBeEdGZk     178.0    128.0  195.0  283.0  502.0  240.0  208.0  245.0
# 550  gJDctCOOhsQ     252.0    333.0  241.0   43.0  306.0  505.0  278.0   58.0
# 551  wmWStFQp0t0     147.0    526.0  530.0  155.0  499.0  540.0  239.0  536.0
#
#      ipron  ...  relig  death  informal  swear  netspeak  assent  nonflu  \
# 0    338.0  ...  132.0  456.0     203.0  146.0     347.0   236.0   171.0
# 1    124.0  ...  288.0  389.0     134.0  398.0     203.0   381.0    80.0
# 2    132.0  ...  368.0  530.0     471.0  498.0     516.0   119.0   437.0
# 3    173.0  ...  301.0  544.0     116.0  408.0     217.0   107.0    69.0
# 4    358.0  ...  132.0  229.0     205.0  308.0     253.0   183.0   225.0
# ..     ...  ...    ...    ...       ...    ...       ...     ...     ...
# 547  347.0  ...  132.0  378.0     546.0  526.0     470.0   550.0   423.0
# 548  329.0  ...  132.0  245.0     262.0  424.0     284.0   366.0   228.5
# 549  176.0  ...  290.0  230.0     303.0  490.0      65.5   285.0   410.0
# 550  427.0  ...  533.0  108.0     443.0  550.0      65.5   296.0   238.0
# 551  293.0  ...  295.0  233.0     301.0  146.0     304.0   191.0   389.0
#
#      filler        group     age
# 0     205.0    White Man  2018.0
# 1     205.0    White Man  2018.0
# 2     417.0    Black Man  2018.0
# 3     415.0    Black Man  2018.0
# 4     534.0  White Woman  2018.0
# ..      ...          ...     ...
# 547   525.0  White Woman  2017.0
# 548   205.0  White Woman  2017.0
# 549   205.0  White Woman  2017.0
# 550   205.0    Black Man  2017.0
# 551   205.0    Black Man  2017.0
#
# [552 rows x 76 columns]

# %% [markdown]
# ## Relevant features
#
# https://www.liwc.net/LIWC2007LanguageManual.pdf
#
# https://repositories.lib.utexas.edu/bitstream/handle/2152/31333/LIWC2015_LanguageManual.pdf

# %%
experiments
# Out:
#      feature  statistic        pvalue
# 0   function  13.118266  4.387704e-03
# 1    pronoun  24.715376  1.770760e-05
# 2      ppron  18.196421  4.006670e-04
# 3          i  11.592505  8.917774e-03
# 4         we   7.618054  5.460147e-02
# ..       ...        ...           ...
# 68     swear  14.489919  2.308751e-03
# 69  netspeak  32.476639  4.152565e-07
# 70    assent  31.594096  6.372621e-07
# 71    nonflu   5.704995  1.268790e-01
# 72    filler  16.142591  1.060148e-03
#
# [73 rows x 3 columns]

# %%
import statsmodels.stats.multitest as smt

# %%
idx = smt.multipletests(pvals=experiments.pvalue, alpha=0.01, method="bonferroni")[0]

# %%
experiments[idx]
# Out:
#       feature  statistic        pvalue
# 1     pronoun  24.715376  1.770760e-05
# 5         you  29.047620  2.188421e-06
# 9     article  32.313947  4.493822e-07
# 12     adverb  23.738495  2.832539e-05
# 13       conj  31.979148  5.286691e-07
# 15       verb  37.131304  4.316250e-08
# 16        adj  29.300763  1.936101e-06
# 19     number  31.956363  5.345469e-07
# 20      quant  45.429640  7.498099e-10
# 54  focuspast  30.944869  8.730746e-07
# 57    relativ  32.394058  4.322421e-07
# 59      space  37.242565  4.088498e-08
# 67   informal  38.059231  2.746028e-08
# 69   netspeak  32.476639  4.152565e-07
# 70     assent  31.594096  6.372621e-07

# %%
interesting_var = experiments[idx].sort_values('pvalue')[:15].feature
interesting_var
# Out:
# 20        quant
# 67     informal
# 59        space
# 15         verb
# 69     netspeak
# 57      relativ
# 9       article
# 13         conj
# 19       number
# 70       assent
# 54    focuspast
# 16          adj
# 5           you
# 1       pronoun
# 12       adverb
# Name: feature, dtype: object

# %%
for 
sns.displot(liwc_df_norm,x = 'informal',hue='group',kind="kde")

# %%
interesting_var = experiments[idx].sort_values('pvalue')[:15].feature
interesting_var
# Out:
# 20        quant
# 67     informal
# 59        space
# 15         verb
# 69     netspeak
# 57      relativ
# 9       article
# 13         conj
# 19       number
# 70       assent
# 54    focuspast
# 16          adj
# 5           you
# 1       pronoun
# 12       adverb
# Name: feature, dtype: object

# %%
print(list(interesting_var))
# Out:
# ['quant', 'informal', 'space', 'verb', 'netspeak', 'relativ', 'article', 'conj', 'number', 'assent', 'focuspast', 'adj', 'you', 'pronoun', 'adverb']

# %%
print(len(experiments[idx]))
print(experiments[idx].sort_values('pvalue')[:15].to_latex())
# Out:
# 15
# \begin{tabular}{llrr}
# \toprule
# {} &    feature &  statistic &        pvalue \\
# \midrule
# 20 &      quant &  45.429640 &  7.498099e-10 \\
# 67 &   informal &  38.059231 &  2.746028e-08 \\
# 59 &      space &  37.242565 &  4.088498e-08 \\
# 15 &       verb &  37.131304 &  4.316250e-08 \\
# 69 &   netspeak &  32.476639 &  4.152565e-07 \\
# 57 &    relativ &  32.394058 &  4.322421e-07 \\
# 9  &    article &  32.313947 &  4.493822e-07 \\
# 13 &       conj &  31.979148 &  5.286691e-07 \\
# 19 &     number &  31.956363 &  5.345469e-07 \\
# 70 &     assent &  31.594096 &  6.372621e-07 \\
# 54 &  focuspast &  30.944869 &  8.730746e-07 \\
# 16 &        adj &  29.300763 &  1.936101e-06 \\
# 5  &        you &  29.047620 &  2.188421e-06 \\
# 1  &    pronoun &  24.715376 &  1.770760e-05 \\
# 12 &     adverb &  23.738495 &  2.832539e-05 \\
# \bottomrule
# \end{tabular}

# %%
experiments.set_index('feature').sort_values('pvalue').pvalue[::-1][:15].plot.barh()
plt.show()

# %%
plt.plot(experiments.pvalue)
plt.show()

# %%
sns.displot(liwc_df_rank, x="cogproc", hue="group", kind="ecdf",complementary=True) #dicionario de palavroes do liwc
plt.savefig('cogproc.pdf')

# %% [markdown]
# ### quant

# %%
interesting_var
# Out:
# 20        quant
# 67     informal
# 59        space
# 15         verb
# 69     netspeak
# 57      relativ
# 9       article
# 13         conj
# 19       number
# 70       assent
# 54    focuspast
# 16          adj
# 5           you
# 1       pronoun
# 12       adverb
# Name: feature, dtype: object

# %%
fig, axes = plt.subplots(3, 5,sharey=True,sharex=False,figsize=(16,8))
axes = axes.ravel()

for i,var in enumerate(interesting_var): 
#     aux = liwx_df
    if i==7:
        g = sns.ecdfplot(liwc_df_norm, x=var, hue="group",complementary=True, ax=axes[i],legend=True) 
        g.legend_.set_title(None)
        new_labels = ['WM', 'BM','WW','BW']
        for t, l in zip(g.legend_.texts, new_labels):
            t.set_text(l)
        g.legend_.set_frame_on(False)
        g.legend_.set_frame_on(False)
    else:
        sns.ecdfplot(liwc_df_norm, x=var, hue="group",complementary=True, ax=axes[i],legend=False)#,hue_norm=(500,500,500,500)) 
    axes[i].set(ylabel='P[X>x]',xlabel='%s score - x'%var)


fig.tight_layout()
plt.savefig('liwc_dists.pdf')
plt.show()

# %%
g.line

# %%
g.legend.

# %% [markdown]
# ## Black people use more informalities

# %%
sns.displot(liwc_df_rank, x="informal", hue="group", kind="ecdf",complementary=True) #dicionario de palavroes do liwc
plt.show()
plt.savefig('informal.pdf')

# %%
sns.displot(liwc_df_rank, x="netspeak", hue="group", kind="ecdf",complementary=True, legend=False) #dicionario de palavroes do liwc
plt.savefig('netspeak.pdf')

# %%
sns.displot(liwc_df_rank, x="assent", hue="group", kind="ecdf",complementary=True, legend=False) #
plt.savefig('assent.pdf')

# %%
sns.displot(liwc_df_rank, x="filler", hue="group", kind="ecdf",complementary=True, legend=False) #
plt.savefig('filler.pdf')

# %%
display(liwc_df_norm[['informal','group']].groupby('group').mean(),liwc_df_rank[['informal','group']].groupby('group').mean())
# Out:
#              informal
# group
# Black Man    0.004713
# Black Woman  0.005030
# White Man    0.003368
# White Woman  0.003668
#                informal
# group
# Black Man    344.160494
# Black Woman  368.559524
# White Man    247.206767
# White Woman  267.200617

# %% [markdown]
# # cogproc

# %%
display(liwc_df_norm[['cogproc','group']].groupby('group').mean(),liwc_df_rank[['cogproc','group']].groupby('group').mean())
# Out:
#               cogproc
# group
# Black Man    0.041737
# Black Woman  0.042310
# White Man    0.043198
# White Woman  0.044043
#                 cogproc
# group
# Black Man    244.283951
# Black Woman  254.011905
# White Man    274.783835
# White Woman  300.518519

# %% [markdown]
# ## Others stats

# %% [markdown]
# ### swear - fuck, damn, shit

# %%
sns.displot(liwc_df_rank, x="swear", hue="group", kind="ecdf",complementary=True, legend=False) #dicionario de palavroes do liwc
plt.savefig('swear.pdf')

# %%
display(liwc_df_norm[['swear','group']].groupby('group').mean(),liwc_df_rank[['swear','group']].groupby('group').mean())
# Out:
#                 swear
# group
# Black Man    0.000406
# Black Woman  0.000327
# White Man    0.000233
# White Woman  0.000270
#                   swear
# group
# Black Man    319.975309
# Black Woman  310.595238
# White Man    256.112782
# White Woman  280.203704

# %% [markdown]
# ### prep - prepositions - to, with, above

# %%
sns.displot(liwc_df_rank, x="prep", hue="group", kind="ecdf",complementary=True) #dicionario de palavroes do liwc
plt.savefig('prep.pdf')

# %% [markdown]
# ### anx - worried, fearful

# %%
sns.displot(liwc_df_rank, x="anx", hue="group", kind="ecdf",complementary=True) #dicionario de palavroes do liwc
plt.show()

# %% [markdown]
# ### percept - Perceptual processes - look, heard, feeling

# %%
sns.displot(liwc_df_rank, x="percept", hue="group", kind="ecdf",complementary=True) #dicionario de palavroes do liwc
plt.show()

# %% [markdown]
# ### conj - Conjunctions - and, but, whereas

# %%
sns.displot(liwc_df_rank, x="conj", hue="group", kind="ecdf",complementary=True, legend=False) #dicionario de palavroes do liwc
plt.savefig('conj.pdf')

# %% [markdown]
# ### function - Total function words - it, to, no, very

# %%
sns.displot(liwc_df_rank, x="function", hue="group", kind="ecdf",complementary=True, legend=False) #dicionario de palavroes do liwc
plt.savefig('function.pdf')

# %% [markdown]
# ---
# # investigating each category most used words by group

# %%
str(list(liwc.parse([word]).keys()))
# Out:
# "['social', 'relativ', 'time']"

# %%
categories = ['informal','cogproc', 'swear','anx','percept'] # liwc.categories.values()

groups_counts = {} # pd.DataFrame(columns=['group','category','word','count'])
groups_counts_df = pd.DataFrame(columns=['categories','count','group','word']).set_index(['group','word'])

for group in df.group.unique():
    for sent in tqdm(df[df.group==group]['text_clean'].str.split(' ')):
        for word in sent:
            if (group,word) not in groups_counts_df.index:
                groups_counts_df.loc[(group,word),:] = (str(list(liwc.parse([word]).keys())),1)
            else:
                groups_counts_df.loc[(group,word),'count'] += 1
groups_counts_df = groups_counts_df.reset_index()
# Out:
# 100%|██████████| 266/266 [08:44<00:00,  1.97s/it]
# 100%|██████████| 82/82 [10:01<00:00,  7.34s/it]
# 100%|██████████| 162/162 [24:22<00:00,  9.03s/it]
# 100%|██████████| 42/42 [18:15<00:00, 26.08s/it]

# %%
data = json.load(open('../data/bad_words_scored.json'))
word_scores = pd.DataFrame({'words':data.keys(),'score': data.values()})

# %%
# groups_counts_df.to_csv('../data/categories_groups_counts_df.csv',index=False)

# %%
groups_counts_df
# Out:
#              group     word                               categories  count
# 0        White Man        I                                       []   6615
# 1        White Man      saw  ['verb', 'percept', 'see', 'focuspast']    149
# 2        White Man    black                       ['percept', 'see']    120
# 3        White Man  panther                                       []     19
# 4        White Man      and                     ['function', 'conj']  12915
# ...            ...      ...                                      ...    ...
# 45640  Black Woman    jimmy                                       []      2
# 45641  Black Woman    cagne                                       []      1
# 45642  Black Woman      jim                                       []      1
# 45643  Black Woman   cagney                                       []      2
# 45644  Black Woman  stewart                                       []      1
#
# [45645 rows x 4 columns]

# %% [markdown]
# ### informal

# %%
bw_informal = groups_counts_df[
    (groups_counts_df.group=='Black Woman') & (groups_counts_df.categories.str.contains('informal'))
]
bw_informal['freq'] = bw_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
bw_informal.sort_values('count',ascending=False).head(20).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-199-fa7bdd924ab0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bw_informal['freq'] = bw_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
#           group        word  \
# 0   Black Woman          oh
# 1   Black Woman       gonna
# 2   Black Woman        okay
# 3   Black Woman        well
# 4   Black Woman          um
# 5   Black Woman        yeah
# 6   Black Woman         yes
# 7   Black Woman        cool
# 8   Black Woman         hey
# 9   Black Woman  absolutely
# 10  Black Woman          uh
# 11  Black Woman      anyway
# 12  Black Woman         cuz
# 13  Black Woman     alright
# 14  Black Woman     awesome
# 15  Black Woman    freaking
# 16  Black Woman        damn
# 17  Black Woman        dude
# 18  Black Woman          ok
# 19  Black Woman          ah
#
#                                            categories count         freq  \
# 0                              ['informal', 'nonflu']   251   0.00296389
# 1   ['verb', 'focusfuture', 'relativ', 'motion', '...   173   0.00204284
# 2          ['affect', 'posemo', 'informal', 'assent']   155   0.00183029
# 3   ['function', 'adverb', 'affect', 'posemo', 'in...   143   0.00168859
# 4                              ['informal', 'nonflu']   119   0.00140519
# 5                              ['informal', 'assent']   105   0.00123987
# 6                              ['informal', 'assent']    45  0.000531375
# 7   ['adj', 'affect', 'posemo', 'percept', 'feel',...    29  0.000342441
# 8                              ['social', 'informal']    29  0.000342441
# 9   ['function', 'adverb', 'cogproc', 'certain', '...    27  0.000318825
# 10                             ['informal', 'nonflu']    26  0.000307017
# 11       ['function', 'adverb', 'informal', 'filler']    21  0.000247975
# 12  ['function', 'conj', 'cogproc', 'cause', 'info...    19  0.000224358
# 13         ['affect', 'posemo', 'informal', 'assent']    17  0.000200742
# 14  ['adj', 'affect', 'posemo', 'informal', 'assent']    16  0.000188933
# 15          ['affect', 'negemo', 'informal', 'swear']    16  0.000188933
# 16  ['affect', 'negemo', 'anger', 'informal', 'swe...    12    0.0001417
# 17                   ['social', 'friend', 'informal']    12    0.0001417
# 18         ['affect', 'posemo', 'informal', 'assent']    10  0.000118083
# 19                   ['informal', 'assent', 'nonflu']    10  0.000118083
#
#    words     score
# 0    NaN       NaN
# 1    NaN       NaN
# 2    NaN       NaN
# 3    NaN       NaN
# 4    NaN       NaN
# 5    NaN       NaN
# 6    NaN       NaN
# 7    NaN       NaN
# 8    NaN       NaN
# 9    NaN       NaN
# 10   NaN       NaN
# 11   NaN       NaN
# 12   NaN       NaN
# 13   NaN       NaN
# 14   NaN       NaN
# 15   NaN       NaN
# 16  damn  0.779738
# 17   NaN       NaN
# 18   NaN       NaN
# 19   NaN       NaN

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='White Man') & (groups_counts_df.categories.str.contains('informal'))
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Man')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(20).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-200-57f1bdac38f0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Man')]['count'].sum()
#         group        word                                         categories  \
# 0   White Man        well  ['function', 'adverb', 'affect', 'posemo', 'in...
# 1   White Man       gonna  ['verb', 'focusfuture', 'relativ', 'motion', '...
# 2   White Man        yeah                             ['informal', 'assent']
# 3   White Man          uh                             ['informal', 'nonflu']
# 4   White Man          um                             ['informal', 'nonflu']
# 5   White Man          oh                             ['informal', 'nonflu']
# 6   White Man  absolutely  ['function', 'adverb', 'cogproc', 'certain', '...
# 7   White Man        okay         ['affect', 'posemo', 'informal', 'assent']
# 8   White Man        cool  ['adj', 'affect', 'posemo', 'percept', 'feel',...
# 9   White Man         yes                             ['informal', 'assent']
# 10  White Man         hey                             ['social', 'informal']
# 11  White Man     awesome  ['adj', 'affect', 'posemo', 'informal', 'assent']
# 12  White Man      anyway       ['function', 'adverb', 'informal', 'filler']
# 13  White Man       gotta    ['verb', 'focusfuture', 'informal', 'netspeak']
# 14  White Man         cuz  ['function', 'conj', 'cogproc', 'cause', 'info...
# 15  White Man        damn  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 16  White Man     alright         ['affect', 'posemo', 'informal', 'assent']
# 17  White Man        hell  ['affect', 'negemo', 'anger', 'relig', 'inform...
# 18  White Man        dude                   ['social', 'friend', 'informal']
# 19  White Man       agree         ['affect', 'posemo', 'informal', 'assent']
#
#    count         freq words     score
# 0    864   0.00235558   NaN       NaN
# 1    565    0.0015404   NaN       NaN
# 2    301  0.000820638   NaN       NaN
# 3    202  0.000550727   NaN       NaN
# 4    199  0.000542548   NaN       NaN
# 5    195  0.000531642   NaN       NaN
# 6    174  0.000474388   NaN       NaN
# 7    141  0.000384418   NaN       NaN
# 8    110  0.000299901   NaN       NaN
# 9    108  0.000294448   NaN       NaN
# 10    65  0.000177214   NaN       NaN
# 11    60  0.000163582   NaN       NaN
# 12    53  0.000144498   NaN       NaN
# 13    47  0.000128139   NaN       NaN
# 14    39  0.000106328   NaN       NaN
# 15    32  8.72439e-05  damn  0.779738
# 16    31  8.45175e-05   NaN       NaN
# 17    28  7.63384e-05  hell  0.483667
# 18    25  6.81593e-05   NaN       NaN
# 19    20  5.45274e-05   NaN       NaN

# %% [markdown]
# ### swear

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='Black Woman') & (groups_counts_df.categories.str.contains('swear'))
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(20).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-201-2d8500db1ce1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
#           group       word                                         categories  \
# 0   Black Woman   freaking          ['affect', 'negemo', 'informal', 'swear']
# 1   Black Woman       damn  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 2   Black Woman       hell  ['affect', 'negemo', 'anger', 'relig', 'inform...
# 3   Black Woman      sucks  ['verb', 'affect', 'negemo', 'anger', 'focuspr...
# 4   Black Woman     badass                              ['informal', 'swear']
# 5   Black Woman       dumb  ['adj', 'affect', 'negemo', 'anger', 'informal...
# 6   Black Woman       dang                              ['informal', 'swear']
# 7   Black Woman    freakin          ['affect', 'negemo', 'informal', 'swear']
# 8   Black Woman     sucked  ['verb', 'affect', 'negemo', 'anger', 'focuspa...
# 9   Black Woman        ass               ['bio', 'body', 'informal', 'swear']
# 10  Black Woman       darn                              ['informal', 'swear']
# 11  Black Woman    goddamn  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 12  Black Woman      idiot  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 13  Black Woman       suck  ['verb', 'affect', 'negemo', 'anger', 'focuspr...
# 14  Black Woman      asses               ['bio', 'body', 'informal', 'swear']
# 15  Black Woman     crappy  ['adj', 'affect', 'negemo', 'anger', 'informal...
# 16  Black Woman  screw-ups  ['affect', 'negemo', 'anger', 'bio', 'sexual',...
# 17  Black Woman      screw  ['affect', 'negemo', 'anger', 'bio', 'sexual',...
# 18  Black Woman  douchebag                              ['informal', 'swear']
# 19  Black Woman   bastards  ['affect', 'negemo', 'anger', 'informal', 'swe...
#
#    count         freq    words     score
# 0     16  0.000188933      NaN       NaN
# 1     12    0.0001417     damn  0.779738
# 2      8  9.44666e-05     hell  0.483667
# 3      5  5.90416e-05      NaN       NaN
# 4      5  5.90416e-05      NaN       NaN
# 5      5  5.90416e-05     dumb  0.845482
# 6      4  4.72333e-05      NaN       NaN
# 7      4  4.72333e-05      NaN       NaN
# 8      4  4.72333e-05      NaN       NaN
# 9      2  2.36167e-05      ass  0.932329
# 10     1  1.18083e-05      NaN       NaN
# 11     1  1.18083e-05  goddamn  0.878531
# 12     1  1.18083e-05    idiot  0.950550
# 13     1  1.18083e-05     suck  0.909938
# 14     1  1.18083e-05    asses  0.835521
# 15     1  1.18083e-05   crappy  0.599151
# 16     1  1.18083e-05      NaN       NaN
# 17     1  1.18083e-05    screw  0.435482
# 18     1  1.18083e-05      NaN       NaN
# 19     1  1.18083e-05      NaN       NaN

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='White Woman') & (groups_counts_df.categories.str.contains('swear'))
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Woman')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(20).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-203-b17cb5e83f6b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Woman')]['count'].sum()
#           group      word                                         categories  \
# 0   White Woman    badass                              ['informal', 'swear']
# 1   White Woman      damn  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 2   White Woman      hell  ['affect', 'negemo', 'anger', 'relig', 'inform...
# 3   White Woman       ass               ['bio', 'body', 'informal', 'swear']
# 4   White Woman      heck                              ['informal', 'swear']
# 5   White Woman      butt               ['bio', 'body', 'informal', 'swear']
# 6   White Woman  freaking          ['affect', 'negemo', 'informal', 'swear']
# 7   White Woman    sucked  ['verb', 'affect', 'negemo', 'anger', 'focuspa...
# 8   White Woman    shitty  ['affect', 'negemo', 'anger', 'bio', 'body', '...
# 9   White Woman     hella                  ['informal', 'swear', 'netspeak']
# 10  White Woman     sucks  ['verb', 'affect', 'negemo', 'anger', 'focuspr...
# 11  White Woman   freakin          ['affect', 'negemo', 'informal', 'swear']
# 12  White Woman      dumb  ['adj', 'affect', 'negemo', 'anger', 'informal...
# 13  White Woman    pissed  ['affect', 'negemo', 'anger', 'bio', 'body', '...
# 14  White Woman      dick     ['bio', 'body', 'sexual', 'informal', 'swear']
# 15  White Woman      crap  ['affect', 'negemo', 'anger', 'bio', 'body', '...
# 16  White Woman   goddamn  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 17  White Woman   screwed  ['affect', 'negemo', 'anger', 'bio', 'sexual',...
# 18  White Woman      suck  ['verb', 'affect', 'negemo', 'anger', 'focuspr...
# 19  White Woman      darn                              ['informal', 'swear']
#
#    count         freq    words     score
# 0     19  7.90412e-05      NaN       NaN
# 1     13  5.40808e-05     damn  0.779738
# 2     12  4.99208e-05     hell  0.483667
# 3     12  4.99208e-05      ass  0.932329
# 4     12  4.99208e-05      NaN       NaN
# 5      9  3.74406e-05     butt  0.769914
# 6      9  3.74406e-05      NaN       NaN
# 7      9  3.74406e-05      NaN       NaN
# 8      9  3.74406e-05   shitty  0.949928
# 9      9  3.74406e-05      NaN       NaN
# 10     9  3.74406e-05      NaN       NaN
# 11     6  2.49604e-05      NaN       NaN
# 12     6  2.49604e-05     dumb  0.845482
# 13     4  1.66403e-05   pissed  0.509258
# 14     4  1.66403e-05     dick  0.901710
# 15     3  1.24802e-05     crap  0.835521
# 16     3  1.24802e-05  goddamn  0.878531
# 17     3  1.24802e-05      NaN       NaN
# 18     3  1.24802e-05     suck  0.909938
# 19     2  8.32013e-06      NaN       NaN

# %% [markdown]
# ### cogproc

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='Black Woman') & (groups_counts_df.categories.str.contains('cogproc'))
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(20).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-212-e4a29866a6bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
#           group       word                                         categories  \
# 0   Black Woman       know     ['verb', 'cogproc', 'insight', 'focuspresent']
# 1   Black Woman        but          ['function', 'conj', 'cogproc', 'differ']
# 2   Black Woman     really        ['function', 'adverb', 'cogproc', 'differ']
# 3   Black Woman        not        ['function', 'negate', 'cogproc', 'differ']
# 4   Black Woman    because           ['function', 'conj', 'cogproc', 'cause']
# 5   Black Woman        all                    ['quant', 'cogproc', 'certain']
# 6   Black Woman         if  ['function', 'conj', 'cogproc', 'discrep', 'te...
# 7   Black Woman      think     ['verb', 'cogproc', 'insight', 'focuspresent']
# 8   Black Woman        how  ['function', 'adverb', 'conj', 'interrog', 'co...
# 9   Black Woman         or  ['function', 'conj', 'cogproc', 'tentat', 'dif...
# 10  Black Woman      would  ['function', 'auxverb', 'verb', 'cogproc', 'di...
# 11  Black Woman       some                     ['quant', 'cogproc', 'tentat']
# 12  Black Woman       want     ['verb', 'cogproc', 'discrep', 'focuspresent']
# 13  Black Woman        lot                     ['quant', 'cogproc', 'tentat']
# 14  Black Woman       feel  ['verb', 'cogproc', 'insight', 'percept', 'fee...
# 15  Black Woman     didn't  ['function', 'auxverb', 'negate', 'verb', 'cog...
# 16  Black Woman   actually        ['function', 'adverb', 'cogproc', 'differ']
# 17  Black Woman       make       ['verb', 'cogproc', 'cause', 'focuspresent']
# 18  Black Woman  something  ['function', 'pronoun', 'ipron', 'cogproc', 't...
# 19  Black Woman        why  ['function', 'adverb', 'interrog', 'cogproc', ...
#
#    count        freq words  score
# 0    646  0.00762818   NaN    NaN
# 1    643  0.00759275   NaN    NaN
# 2    489  0.00577427   NaN    NaN
# 3    456   0.0053846   NaN    NaN
# 4    393  0.00464067   NaN    NaN
# 5    337  0.00397941   NaN    NaN
# 6    309  0.00364877   NaN    NaN
# 7    268  0.00316463   NaN    NaN
# 8    251  0.00296389   NaN    NaN
# 9    230  0.00271592   NaN    NaN
# 10   199  0.00234986   NaN    NaN
# 11   180   0.0021255   NaN    NaN
# 12   168   0.0019838   NaN    NaN
# 13   159  0.00187752   NaN    NaN
# 14   150  0.00177125   NaN    NaN
# 15   139  0.00164136   NaN    NaN
# 16   136  0.00160593   NaN    NaN
# 17   130  0.00153508   NaN    NaN
# 18   116  0.00136977   NaN    NaN
# 19   112  0.00132253   NaN    NaN

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='White Man') & (groups_counts_df.categories.str.contains('cogproc'))
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Man')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(20).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-213-8cb6bfc60f3c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Man')]['count'].sum()
#         group       word                                         categories  \
# 0   White Man        but          ['function', 'conj', 'cogproc', 'differ']
# 1   White Man     really        ['function', 'adverb', 'cogproc', 'differ']
# 2   White Man       know     ['verb', 'cogproc', 'insight', 'focuspresent']
# 3   White Man        not        ['function', 'negate', 'cogproc', 'differ']
# 4   White Man        all                    ['quant', 'cogproc', 'certain']
# 5   White Man    because           ['function', 'conj', 'cogproc', 'cause']
# 6   White Man      think     ['verb', 'cogproc', 'insight', 'focuspresent']
# 7   White Man         if  ['function', 'conj', 'cogproc', 'discrep', 'te...
# 8   White Man         or  ['function', 'conj', 'cogproc', 'tentat', 'dif...
# 9   White Man       some                     ['quant', 'cogproc', 'tentat']
# 10  White Man        lot                     ['quant', 'cogproc', 'tentat']
# 11  White Man        how  ['function', 'adverb', 'conj', 'interrog', 'co...
# 12  White Man      would  ['function', 'auxverb', 'verb', 'cogproc', 'di...
# 13  White Man      other  ['function', 'pronoun', 'ipron', 'cogproc', 'd...
# 14  White Man   actually        ['function', 'adverb', 'cogproc', 'differ']
# 15  White Man       feel  ['verb', 'cogproc', 'insight', 'percept', 'fee...
# 16  White Man       want     ['verb', 'cogproc', 'discrep', 'focuspresent']
# 17  White Man  something  ['function', 'pronoun', 'ipron', 'cogproc', 't...
# 18  White Man       most   ['adj', 'compare', 'quant', 'cogproc', 'tentat']
# 19  White Man       make       ['verb', 'cogproc', 'cause', 'focuspresent']
#
#    count        freq words  score
# 0   2934  0.00799917   NaN    NaN
# 1   2529  0.00689499   NaN    NaN
# 2   1989  0.00542275   NaN    NaN
# 3   1653  0.00450669   NaN    NaN
# 4   1573  0.00428858   NaN    NaN
# 5   1327  0.00361789   NaN    NaN
# 6   1316   0.0035879   NaN    NaN
# 7   1231  0.00335616   NaN    NaN
# 8   1064  0.00290086   NaN    NaN
# 9   1029  0.00280544   NaN    NaN
# 10   933   0.0025437   NaN    NaN
# 11   817  0.00222744   NaN    NaN
# 12   575  0.00156766   NaN    NaN
# 13   572  0.00155948   NaN    NaN
# 14   544  0.00148315   NaN    NaN
# 15   538  0.00146679   NaN    NaN
# 16   536  0.00146133   NaN    NaN
# 17   496  0.00135228   NaN    NaN
# 18   441  0.00120233   NaN    NaN
# 19   422  0.00115053   NaN    NaN

# %% [markdown]
# ### anx

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='Black Woman') & (groups_counts_df.categories.str.contains('anx'))
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(20).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-215-64f77ba7253e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
#           group           word  \
# 0   Black Woman          scary
# 1   Black Woman         horror
# 2   Black Woman           fear
# 3   Black Woman         scared
# 4   Black Woman            shy
# 5   Black Woman  uncomfortable
# 6   Black Woman     terrifying
# 7   Black Woman       horrible
# 8   Black Woman          shook
# 9   Black Woman         afraid
# 10  Black Woman          tense
# 11  Black Woman        shaking
# 12  Black Woman       confused
# 13  Black Woman        awkward
# 14  Black Woman        worried
# 15  Black Woman         threat
# 16  Black Woman       struggle
# 17  Black Woman          worry
# 18  Black Woman          scare
# 19  Black Woman      struggles
#
#                                            categories count         freq  \
# 0                  ['adj', 'affect', 'negemo', 'anx']    32  0.000377866
# 1                         ['affect', 'negemo', 'anx']    29  0.000342441
# 2                         ['affect', 'negemo', 'anx']    14  0.000165317
# 3                  ['adj', 'affect', 'negemo', 'anx']    11  0.000129892
# 4        ['adj', 'affect', 'negemo', 'anx', 'social']     9  0.000106275
# 5                         ['affect', 'negemo', 'anx']     6    7.085e-05
# 6                  ['adj', 'affect', 'negemo', 'anx']     6    7.085e-05
# 7                  ['adj', 'affect', 'negemo', 'anx']     5  5.90416e-05
# 8   ['verb', 'affect', 'negemo', 'anx', 'focuspast...     5  5.90416e-05
# 9                  ['adj', 'affect', 'negemo', 'anx']     5  5.90416e-05
# 10                        ['affect', 'negemo', 'anx']     4  4.72333e-05
# 11                        ['affect', 'negemo', 'anx']     4  4.72333e-05
# 12   ['affect', 'negemo', 'anx', 'cogproc', 'tentat']     4  4.72333e-05
# 13              ['affect', 'negemo', 'anx', 'social']     4  4.72333e-05
# 14                 ['adj', 'affect', 'negemo', 'anx']     4  4.72333e-05
# 15  ['affect', 'negemo', 'anx', 'anger', 'drives',...     3   3.5425e-05
# 16     ['affect', 'negemo', 'anx', 'drives', 'power']     3   3.5425e-05
# 17  ['verb', 'affect', 'negemo', 'anx', 'focuspres...     3   3.5425e-05
# 18                        ['affect', 'negemo', 'anx']     3   3.5425e-05
# 19     ['affect', 'negemo', 'anx', 'drives', 'power']     3   3.5425e-05
#
#    words     score
# 0    NaN       NaN
# 1    NaN       NaN
# 2   fear  0.142798
# 3    NaN       NaN
# 4    NaN       NaN
# 5    NaN       NaN
# 6    NaN       NaN
# 7    NaN       NaN
# 8    NaN       NaN
# 9    NaN       NaN
# 10   NaN       NaN
# 11   NaN       NaN
# 12   NaN       NaN
# 13   NaN       NaN
# 14   NaN       NaN
# 15   NaN       NaN
# 16   NaN       NaN
# 17   NaN       NaN
# 18   NaN       NaN
# 19   NaN       NaN

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='White Woman') & (groups_counts_df.categories.str.contains('anx'))
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Man')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(20).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-216-c228f5d16615>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Man')]['count'].sum()
#           group           word  \
# 0   White Woman         horror
# 1   White Woman        tension
# 2   White Woman          worry
# 3   White Woman          scary
# 4   White Woman           fear
# 5   White Woman        awkward
# 6   White Woman        worried
# 7   White Woman  uncomfortable
# 8   White Woman     terrifying
# 9   White Woman     struggling
# 10  White Woman       horrible
# 11  White Woman       struggle
# 12  White Woman         scared
# 13  White Woman        nervous
# 14  White Woman          tense
# 15  White Woman         afraid
# 16  White Woman         scares
# 17  White Woman            shy
# 18  White Woman          doubt
# 19  White Woman      confusing
#
#                                            categories count         freq  \
# 0                         ['affect', 'negemo', 'anx']   134  0.000365334
# 1                         ['affect', 'negemo', 'anx']    59  0.000160856
# 2   ['verb', 'affect', 'negemo', 'anx', 'focuspres...    28  7.63384e-05
# 3                  ['adj', 'affect', 'negemo', 'anx']    26  7.08856e-05
# 4                         ['affect', 'negemo', 'anx']    22  5.99802e-05
# 5               ['affect', 'negemo', 'anx', 'social']    21  5.72538e-05
# 6                  ['adj', 'affect', 'negemo', 'anx']    18  4.90747e-05
# 7                         ['affect', 'negemo', 'anx']    17  4.63483e-05
# 8                  ['adj', 'affect', 'negemo', 'anx']    17  4.63483e-05
# 9      ['affect', 'negemo', 'anx', 'drives', 'power']    16  4.36219e-05
# 10                 ['adj', 'affect', 'negemo', 'anx']    16  4.36219e-05
# 11     ['affect', 'negemo', 'anx', 'drives', 'power']    15  4.08956e-05
# 12                 ['adj', 'affect', 'negemo', 'anx']    15  4.08956e-05
# 13                 ['adj', 'affect', 'negemo', 'anx']    15  4.08956e-05
# 14                        ['affect', 'negemo', 'anx']    14  3.81692e-05
# 15                 ['adj', 'affect', 'negemo', 'anx']    13  3.54428e-05
# 16  ['verb', 'affect', 'negemo', 'anx', 'focuspres...    13  3.54428e-05
# 17       ['adj', 'affect', 'negemo', 'anx', 'social']    13  3.54428e-05
# 18  ['affect', 'negemo', 'anx', 'cogproc', 'tentat...    13  3.54428e-05
# 19   ['affect', 'negemo', 'anx', 'cogproc', 'tentat']    12  3.27164e-05
#
#    words     score
# 0    NaN       NaN
# 1    NaN       NaN
# 2    NaN       NaN
# 3    NaN       NaN
# 4   fear  0.142798
# 5    NaN       NaN
# 6    NaN       NaN
# 7    NaN       NaN
# 8    NaN       NaN
# 9    NaN       NaN
# 10   NaN       NaN
# 11   NaN       NaN
# 12   NaN       NaN
# 13   NaN       NaN
# 14   NaN       NaN
# 15   NaN       NaN
# 16   NaN       NaN
# 17   NaN       NaN
# 18   NaN       NaN
# 19   NaN       NaN

# %% [markdown]
# ### quant

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='Black Woman') & groups_counts_df.categories.str.contains('informal') & groups_counts_df.categories.str.contains('swear')
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(30).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-290-9e461a842f48>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='Black Woman')]['count'].sum()
#           group       word                                         categories  \
# 0   Black Woman   freaking          ['affect', 'negemo', 'informal', 'swear']
# 1   Black Woman       damn  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 2   Black Woman       hell  ['affect', 'negemo', 'anger', 'relig', 'inform...
# 3   Black Woman      sucks  ['verb', 'affect', 'negemo', 'anger', 'focuspr...
# 4   Black Woman     badass                              ['informal', 'swear']
# 5   Black Woman       dumb  ['adj', 'affect', 'negemo', 'anger', 'informal...
# 6   Black Woman       dang                              ['informal', 'swear']
# 7   Black Woman    freakin          ['affect', 'negemo', 'informal', 'swear']
# 8   Black Woman     sucked  ['verb', 'affect', 'negemo', 'anger', 'focuspa...
# 9   Black Woman        ass               ['bio', 'body', 'informal', 'swear']
# 10  Black Woman       darn                              ['informal', 'swear']
# 11  Black Woman    goddamn  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 12  Black Woman      idiot  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 13  Black Woman       suck  ['verb', 'affect', 'negemo', 'anger', 'focuspr...
# 14  Black Woman      asses               ['bio', 'body', 'informal', 'swear']
# 15  Black Woman     crappy  ['adj', 'affect', 'negemo', 'anger', 'informal...
# 16  Black Woman  screw-ups  ['affect', 'negemo', 'anger', 'bio', 'sexual',...
# 17  Black Woman      screw  ['affect', 'negemo', 'anger', 'bio', 'sexual',...
# 18  Black Woman  douchebag                              ['informal', 'swear']
# 19  Black Woman   bastards  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 20  Black Woman    pissing  ['affect', 'negemo', 'anger', 'bio', 'body', '...
# 21  Black Woman       heck                              ['informal', 'swear']
# 22  Black Woman       boob     ['bio', 'body', 'sexual', 'informal', 'swear']
# 23  Black Woman     geeked          ['affect', 'negemo', 'informal', 'swear']
# 24  Black Woman     idiots  ['affect', 'negemo', 'anger', 'informal', 'swe...
# 25  Black Woman       butt               ['bio', 'body', 'informal', 'swear']
#
#    count         freq    words     score     stem
# 0     16  0.000188933      NaN       NaN      NaN
# 1     12    0.0001417     damn  0.779738     damn
# 2      8  9.44666e-05     hell  0.483667     hell
# 3      5  5.90416e-05      NaN       NaN      NaN
# 4      5  5.90416e-05      NaN       NaN      NaN
# 5      5  5.90416e-05     dumb  0.845482     dumb
# 6      4  4.72333e-05      NaN       NaN      NaN
# 7      4  4.72333e-05      NaN       NaN      NaN
# 8      4  4.72333e-05      NaN       NaN      NaN
# 9      2  2.36167e-05      ass  0.932329      ass
# 10     1  1.18083e-05      NaN       NaN      NaN
# 11     1  1.18083e-05  goddamn  0.878531  goddamn
# 12     1  1.18083e-05    idiot  0.950550    idiot
# 13     1  1.18083e-05     suck  0.909938     suck
# 14     1  1.18083e-05    asses  0.835521      ass
# 15     1  1.18083e-05   crappy  0.599151   crappi
# 16     1  1.18083e-05      NaN       NaN      NaN
# 17     1  1.18083e-05    screw  0.435482    screw
# 18     1  1.18083e-05      NaN       NaN      NaN
# 19     1  1.18083e-05      NaN       NaN      NaN
# 20     1  1.18083e-05  pissing  0.475707     piss
# 21     1  1.18083e-05      NaN       NaN      NaN
# 22     1  1.18083e-05     boob  0.673753     boob
# 23     1  1.18083e-05      NaN       NaN      NaN
# 24     1  1.18083e-05      NaN       NaN      NaN
# 25     1  1.18083e-05     butt  0.769914     butt

# %%
wm_informal = groups_counts_df[
    (groups_counts_df.group=='White Woman') & (groups_counts_df.categories.str.contains('informal')) & groups_counts_df.categories.str.contains('swear')
]
wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Man')]['count'].sum()
wm_informal.sort_values('count',ascending=False).head(30).merge(word_scores, left_on='word', right_on='words',how='left')
# Out:
# <ipython-input-292-2801b55c5b3b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wm_informal['freq'] = wm_informal['count']/groups_counts_df[(groups_counts_df.group=='White Man')]['count'].sum()
#           group        word  \
# 0   White Woman      badass
# 1   White Woman        damn
# 2   White Woman        hell
# 3   White Woman         ass
# 4   White Woman        heck
# 5   White Woman        butt
# 6   White Woman    freaking
# 7   White Woman      sucked
# 8   White Woman      shitty
# 9   White Woman       hella
# 10  White Woman       sucks
# 11  White Woman     freakin
# 12  White Woman        dumb
# 13  White Woman      pissed
# 14  White Woman        dick
# 15  White Woman        crap
# 16  White Woman     goddamn
# 17  White Woman     screwed
# 18  White Woman        suck
# 19  White Woman        darn
# 20  White Woman   screwball
# 21  White Woman        dang
# 22  White Woman      screws
# 23  White Woman     freaked
# 24  White Woman   screwless
# 25  White Woman       geeks
# 26  White Woman       idiot
# 27  White Woman     friggin
# 28  White Woman        dork
# 29  White Woman  shittiness
#
#                                            categories count         freq  \
# 0                               ['informal', 'swear']    19   5.1801e-05
# 1   ['affect', 'negemo', 'anger', 'informal', 'swe...    13  3.54428e-05
# 2   ['affect', 'negemo', 'anger', 'relig', 'inform...    12  3.27164e-05
# 3                ['bio', 'body', 'informal', 'swear']    12  3.27164e-05
# 4                               ['informal', 'swear']    12  3.27164e-05
# 5                ['bio', 'body', 'informal', 'swear']     9  2.45373e-05
# 6           ['affect', 'negemo', 'informal', 'swear']     9  2.45373e-05
# 7   ['verb', 'affect', 'negemo', 'anger', 'focuspa...     9  2.45373e-05
# 8   ['affect', 'negemo', 'anger', 'bio', 'body', '...     9  2.45373e-05
# 9                   ['informal', 'swear', 'netspeak']     9  2.45373e-05
# 10  ['verb', 'affect', 'negemo', 'anger', 'focuspr...     9  2.45373e-05
# 11          ['affect', 'negemo', 'informal', 'swear']     6  1.63582e-05
# 12  ['adj', 'affect', 'negemo', 'anger', 'informal...     6  1.63582e-05
# 13  ['affect', 'negemo', 'anger', 'bio', 'body', '...     4  1.09055e-05
# 14     ['bio', 'body', 'sexual', 'informal', 'swear']     4  1.09055e-05
# 15  ['affect', 'negemo', 'anger', 'bio', 'body', '...     3  8.17911e-06
# 16  ['affect', 'negemo', 'anger', 'informal', 'swe...     3  8.17911e-06
# 17  ['affect', 'negemo', 'anger', 'bio', 'sexual',...     3  8.17911e-06
# 18  ['verb', 'affect', 'negemo', 'anger', 'focuspr...     3  8.17911e-06
# 19                              ['informal', 'swear']     2  5.45274e-06
# 20  ['affect', 'negemo', 'anger', 'bio', 'sexual',...     2  5.45274e-06
# 21                              ['informal', 'swear']     2  5.45274e-06
# 22  ['affect', 'negemo', 'anger', 'bio', 'sexual',...     2  5.45274e-06
# 23          ['affect', 'negemo', 'informal', 'swear']     1  2.72637e-06
# 24  ['affect', 'negemo', 'anger', 'bio', 'sexual',...     1  2.72637e-06
# 25          ['affect', 'negemo', 'informal', 'swear']     1  2.72637e-06
# 26  ['affect', 'negemo', 'anger', 'informal', 'swe...     1  2.72637e-06
# 27                              ['informal', 'swear']     1  2.72637e-06
# 28          ['affect', 'negemo', 'informal', 'swear']     1  2.72637e-06
# 29  ['affect', 'negemo', 'anger', 'bio', 'body', '...     1  2.72637e-06
#
#       words     score     stem
# 0       NaN       NaN      NaN
# 1      damn  0.779738     damn
# 2      hell  0.483667     hell
# 3       ass  0.932329      ass
# 4       NaN       NaN      NaN
# 5      butt  0.769914     butt
# 6       NaN       NaN      NaN
# 7       NaN       NaN      NaN
# 8    shitty  0.949928   shitti
# 9       NaN       NaN      NaN
# 10      NaN       NaN      NaN
# 11      NaN       NaN      NaN
# 12     dumb  0.845482     dumb
# 13   pissed  0.509258     piss
# 14     dick  0.901710     dick
# 15     crap  0.835521     crap
# 16  goddamn  0.878531  goddamn
# 17      NaN       NaN      NaN
# 18     suck  0.909938     suck
# 19      NaN       NaN      NaN
# 20      NaN       NaN      NaN
# 21      NaN       NaN      NaN
# 22      NaN       NaN      NaN
# 23      NaN       NaN      NaN
# 24      NaN       NaN      NaN
# 25      NaN       NaN      NaN
# 26    idiot  0.950550    idiot
# 27      NaN       NaN      NaN
# 28      NaN       NaN      NaN
# 29      NaN       NaN      NaN

# %% [markdown]
# ---
# # radar plot

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections.polar import PolarAxes
from matplotlib.projections import register_projection
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D


def radar_factory(num_vars, frame='circle'):
    """
    Create a radar chart with `num_vars` axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle', 'polygon'}
        Shape of frame surrounding axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarAxes(PolarAxes):

        name = 'radar'
        # use 1 line segment to connect specified points
        RESOLUTION = 1

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            # rotate plot such that the first axis is at the top
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            """Override fill so that line is closed by default"""
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            """Override plot so that line is closed by default"""
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.append(x, x[0])
                y = np.append(y, y[0])
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            # The Axes patch must be centered at (0.5, 0.5) and of radius 0.5
            # in axes coordinates.
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                # spine_type must be 'left'/'right'/'top'/'bottom'/'circle'.
                spine = Spine(axes=self,
                              spine_type='circle',
                              path=Path.unit_regular_polygon(num_vars))
                # unit_regular_polygon gives a polygon of radius 1 centered at
                # (0, 0) but we want a polygon of radius 0.5 centered at (0.5,
                # 0.5) in axes coordinates.
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)
                return {'polar': spine}
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

    register_projection(RadarAxes)
    return theta


def example_data():
    # The following data is from the Denver Aerosol Sources and Health study.
    # See doi:10.1016/j.atmosenv.2008.12.017
    #
    # The data are pollution source profile estimates for five modeled
    # pollution sources (e.g., cars, wood-burning, etc) that emit 7-9 chemical
    # species. The radar charts are experimented with here to see if we can
    # nicely visualize how the modeled source profiles change across four
    # scenarios:
    #  1) No gas-phase species present, just seven particulate counts on
    #     Sulfate
    #     Nitrate
    #     Elemental Carbon (EC)
    #     Organic Carbon fraction 1 (OC)
    #     Organic Carbon fraction 2 (OC2)
    #     Organic Carbon fraction 3 (OC3)
    #     Pyrolized Organic Carbon (OP)
    #  2)Inclusion of gas-phase specie carbon monoxide (CO)
    #  3)Inclusion of gas-phase specie ozone (O3).
    #  4)Inclusion of both gas-phase species is present...
    data = [
        ['Sulfate', 'Nitrate', 'EC', 'OC1', 'OC2', 'OC3', 'OP', 'CO', 'O3'],
        ('Basecase', [
            [0.88, 0.01, 0.03, 0.03, 0.00, 0.06, 0.01, 0.00, 0.00],
            [0.07, 0.95, 0.04, 0.05, 0.00, 0.02, 0.01, 0.00, 0.00],
            [0.01, 0.02, 0.85, 0.19, 0.05, 0.10, 0.00, 0.00, 0.00],
            [0.02, 0.01, 0.07, 0.01, 0.21, 0.12, 0.98, 0.00, 0.00],
            [0.01, 0.01, 0.02, 0.71, 0.74, 0.70, 0.00, 0.00, 0.00]]),
        ('With CO', [
            [0.88, 0.02, 0.02, 0.02, 0.00, 0.05, 0.00, 0.05, 0.00],
            [0.08, 0.94, 0.04, 0.02, 0.00, 0.01, 0.12, 0.04, 0.00],
            [0.01, 0.01, 0.79, 0.10, 0.00, 0.05, 0.00, 0.31, 0.00],
            [0.00, 0.02, 0.03, 0.38, 0.31, 0.31, 0.00, 0.59, 0.00],
            [0.02, 0.02, 0.11, 0.47, 0.69, 0.58, 0.88, 0.00, 0.00]]),
        ('With O3', [
            [0.89, 0.01, 0.07, 0.00, 0.00, 0.05, 0.00, 0.00, 0.03],
            [0.07, 0.95, 0.05, 0.04, 0.00, 0.02, 0.12, 0.00, 0.00],
            [0.01, 0.02, 0.86, 0.27, 0.16, 0.19, 0.00, 0.00, 0.00],
            [0.01, 0.03, 0.00, 0.32, 0.29, 0.27, 0.00, 0.00, 0.95],
            [0.02, 0.00, 0.03, 0.37, 0.56, 0.47, 0.87, 0.00, 0.00]]),
        ('CO & O3', [
            [0.87, 0.01, 0.08, 0.00, 0.00, 0.04, 0.00, 0.00, 0.01],
            [0.09, 0.95, 0.02, 0.03, 0.00, 0.01, 0.13, 0.06, 0.00],
            [0.01, 0.02, 0.71, 0.24, 0.13, 0.16, 0.00, 0.50, 0.00],
            [0.01, 0.03, 0.00, 0.28, 0.24, 0.23, 0.00, 0.44, 0.88],
            [0.02, 0.00, 0.18, 0.45, 0.64, 0.55, 0.86, 0.00, 0.16]])
    ]
    return data



N = 9
theta = radar_factory(N, frame='polygon')

data = example_data()
spoke_labels = data.pop(0)

fig, ax = plt.subplots(figsize=(9, 9), nrows=1, ncols=1,
                        subplot_kw=dict(projection='radar'))
fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

colors = ['b', 'r', 'g', 'm', 'y']
# Plot the four cases from the example data on separate axes

ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
ax.set_title(title, weight='bold', size='medium', position=(0.5, 1.1),
             horizontalalignment='center', verticalalignment='center')
for d, color in zip(case_data, colors):
    ax.plot(theta, d, color=color)
    ax.fill(theta, d, facecolor=color, alpha=0.25)
ax.set_varlabels(spoke_labels)

# add legend relative to top-left plot
labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
legend = ax.legend(labels, loc=(0.9, .95),
                          labelspacing=0.1, fontsize='small')

fig.text(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
         horizontalalignment='center', color='black', weight='bold',
         size='large')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b08790a71d01> in <module>
#     156
#     157 ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
# --> 158 ax.set_title(title, weight='bold', size='medium', position=(0.5, 1.1),
#     159              horizontalalignment='center', verticalalignment='center')
#     160 for d, color in zip(case_data, colors):
#
# NameError: name 'title' is not defined

# %% [markdown]
# ---

# %% [markdown]
# # Diferences between groups on toxicity score

# %% [markdown]
# ### Kruskal-wallis test

# %%
result = stats.kruskal(
        df[df.group=='White Man']['score'],
        df[df.group=='White Woman']['score'],
        df[df.group=='Black Man']['score'],
        df[df.group=='Black Woman']['score'],
    )
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-d5c0c28571ad> in <module>
#       1 result = stats.kruskal(
# ----> 2         df[df.group=='White Man']['score'],
#       3         df[df.group=='White Woman']['score'],
#       4         df[df.group=='Black Man']['score'],
#       5         df[df.group=='Black Woman']['score'],
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'score'

# %%
sns.displot(df, x="score", hue="group", kind="ecdf",complementary=True) #checar o que sao adjetivos

# %% [markdown]
# ---

# %% [markdown]
# # Bad Words

# %%
data = json.load(open('../data/bad_words_scored.json'))
word_scores = pd.DataFrame({'words':data.keys(),'score': data.values()})
bad_words = word_scores[word_scores.score>0.2]

# %%
word_scores[word_scores.words=='w']

# %%
import nltk
sno = nltk.stem.SnowballStemmer('english')
word_scores['stem'] = word_scores['words'].apply(lambda x: sno.stem(x)) 
word_scores

# %%
bad_words_counts_df_steam = pd.DataFrame(columns=['count','group','bad_word']).set_index(['group','bad_word'])

for group in df.group.unique():
    for sent in tqdm(df[df.group==group]['text_clean'].str.split(' ')):
        for word in sent:
            if (sno.stem(word) ==word_scores.stem).any():
                if (group,word) not in bad_words_counts_df_steam.index:
                    bad_words_counts_df_steam.loc[(group,word),'count'] = 1
                else:
                    bad_words_counts_df_steam.loc[(group,word),'count'] += 1
bad_words_counts_df_steam = bad_words_counts_df_steam.reset_index()
# Out:
# 100%|██████████| 266/266 [01:24<00:00,  3.14it/s]
# 100%|██████████| 82/82 [00:31<00:00,  2.63it/s]
# 100%|██████████| 162/162 [00:57<00:00,  2.84it/s]
# 100%|██████████| 42/42 [00:19<00:00,  2.16it/s]

# %%
bad_words_counts_df_steam.reset_index()
# Out:
#       index        group bad_word count
# 0         0    White Man    black   120
# 1         1    White Man     dead    47
# 2         2    White Man     kill    22
# 3         3    White Man    Black    45
# 4         4    White Man   killed    17
# ...     ...          ...      ...   ...
# 1288   1288  Black Woman     lied     2
# 1289   1289  Black Woman   Asians     1
# 1290   1290  Black Woman  disease     1
# 1291   1291  Black Woman    blows     1
# 1292   1292  Black Woman   stroke     1
#
# [1293 rows x 4 columns]

# %%
bad_words_counts_df = pd.DataFrame(columns=['count','group','bad_word']).set_index(['group','bad_word'])

for group in df.group.unique():
    for sent in tqdm(df[df.group==group]['text_clean'].str.split(' ')):
        for word in sent:
            if (word ==word_scores.words).any():
                if (group,word) not in bad_words_counts_df.index:
                    bad_words_counts_df.loc[(group,word),'count'] = 1
                else:
                    bad_words_counts_df.loc[(group,word),'count'] += 1
bad_words_counts_df = bad_words_counts_df.reset_index()
# Out:
# 100%|██████████| 266/266 [01:14<00:00,  3.57it/s]
# 100%|██████████| 82/82 [00:28<00:00,  2.85it/s]
# 100%|██████████| 162/162 [00:54<00:00,  2.96it/s]
# 100%|██████████| 42/42 [00:19<00:00,  2.18it/s]

# %%
for group in df.group.unique():
    bad_words_counts_df.loc[bad_words_counts_df.group==group,'freq'] = (
        bad_words_counts_df[bad_words_counts_df.group==group]['count']
        /
        groups_counts_df[groups_counts_df.group==group]['count'].sum()
    )

# %%
bad_words_counts_df = bad_words_counts_df.merge(word_scores, left_on='bad_word',right_on='words')[['group','bad_word','count','freq','score']]

# %%
bad_words_counts_df.to_csv('../data/bad_words_counts_df.csv', index=False)

# %%
bad_words_counts_df[bad_words_counts_df.score>0.2].sort_values('freq',ascending=False).groupby('group').head(10).sort_values(['group','freq'],ascending=False)
# Out:
#            group  bad_word count         freq     score
# 2    White Woman     black    92  0.000382726  0.348820
# 6    White Woman      dead    41  0.000170563  0.441481
# 121  White Woman     death    41  0.000170563  0.636407
# 78   White Woman       die    28  0.000116482  0.709312
# 139  White Woman    murder    26  0.000108162  0.605843
# 181  White Woman  violence    21  8.73613e-05  0.353454
# 228  White Woman      fire    19  7.90412e-05  0.301820
# 106  White Woman      died    16   6.6561e-05  0.363736
# 14   White Woman    killed    16   6.6561e-05  0.664008
# 67   White Woman    stupid    15  6.24009e-05  0.914704
# 0      White Man     black   120  0.000327164  0.348820
# 119    White Man     death    74  0.000201751  0.636407
# 4      White Man      dead    47  0.000128139  0.441481
# 226    White Man      fire    46  0.000125413  0.301820
# 138    White Man    murder    42  0.000114508  0.605843
# 76     White Man       die    38  0.000103602  0.709312
# 37     White Man      damn    32  8.72439e-05  0.779738
# 179    White Man  violence    31  8.45175e-05  0.353454
# 33     White Man      hell    28  7.63384e-05  0.483667
# 261    White Man   killing    26  7.08856e-05  0.635077
# 3    Black Woman     black   137   0.00161774  0.348820
# 7    Black Woman      dead    17  0.000200742  0.441481
# 204  Black Woman       gay    16  0.000188933  0.770292
# 11   Black Woman      kill    16  0.000188933  0.806061
# 40   Black Woman      damn    12    0.0001417  0.779738
# 122  Black Woman     death    10  0.000118083  0.636407
# 36   Black Woman      hell     8  9.44666e-05  0.483667
# 15   Black Woman    killed     8  9.44666e-05  0.664008
# 472  Black Woman    cancer     8  9.44666e-05  0.422982
# 229  Black Woman      fire     7  8.26583e-05  0.301820
# 1      Black Man     black   112  0.000836002  0.348820
# 9      Black Man      kill    43  0.000320965  0.806061
# 322    Black Man      dope    33  0.000246322  0.489401
# 34     Black Man      hell    29  0.000216465  0.483667
# 5      Black Man      dead    27  0.000201536  0.441481
# 13     Black Man    killed    24  0.000179143  0.664008
# 227    Black Man      fire    16  0.000119429  0.301820
# 381    Black Man      crap    13  9.70359e-05  0.835521
# 77     Black Man       die    12  8.95716e-05  0.709312
# 198    Black Man      sick    12  8.95716e-05  0.429812

# %%
bad_words_counts_df[bad_words_counts_df.bad_word=='black']
# Out:
# Empty DataFrame
# Columns: [group, bad_word, count, freq, score, normalized_score]
# Index: []

# %%
bad_words_counts_df[bad_words_counts_df.bad_word=='kill']
# Out:
#           group bad_word count         freq     score  normalized_score
# 8     White Man     kill    22  5.99802e-05  0.806061          0.000048
# 9     Black Man     kill    43  0.000320965  0.806061          0.000259
# 10  White Woman     kill    15  6.24009e-05  0.806061          0.000050
# 11  Black Woman     kill    16  0.000188933  0.806061          0.000152

# %%
bad_words_counts_df[bad_words_counts_df.bad_word=='dead']
# Out:
#          group bad_word count         freq     score  normalized_score
# 4    White Man     dead    47  0.000128139  0.441481          0.000057
# 5    Black Man     dead    27  0.000201536  0.441481          0.000089
# 6  White Woman     dead    41  0.000170563  0.441481          0.000075
# 7  Black Woman     dead    17  0.000200742  0.441481          0.000089

# %%
bad_words_counts_df['normalized_score'] = bad_words_counts_df['freq'] * bad_words_counts_df['score']
bad_words_counts_df['normalized_score'] = bad_words_counts_df['normalized_score'].astype(float)

# %%
bad_words_counts_df.groupby('group',as_index=False).sum()
# Out:
#          group      score  normalized_score
# 0    Black Man  49.243228          0.002319
# 1  Black Woman  44.644553          0.002536
# 2    White Man  67.904789          0.001650
# 3  White Woman  58.857698          0.001687

# %%
def get_word_count(text, word):
    text_s = pd.Series(text.split(' '))
    return (text_s==word).sum()

def get_bad_words_count(text, bad_words):
    total=0
    for bad_word in bad_words:
        total +=get_word_count(text,bad_word)
    return total

# %%
df['bad_words_count'] = df['text_clean'].apply(get_bad_words_count,args=(bad_words.words,))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-186-50683dc11d1f> in <module>
# ----> 1 df['bad_words_count'] = df['text_clean'].apply(get_bad_words_count,args=(bad_words.words,))
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in f(x)
#    4183
#    4184             def f(x):
# -> 4185                 return func(x, *args, **kwds)
#    4186
#    4187         else:
#
# <ipython-input-185-04247d220eac> in get_bad_words_count(text, bad_words)
#       6     total=0
#       7     for bad_word in bad_words:
# ----> 8         total +=get_word_count(text,bad_word)
#       9     return total
#
# <ipython-input-185-04247d220eac> in get_word_count(text, word)
#       1 def get_word_count(text, word):
#       2     text_s = pd.Series(text.split(' '))
# ----> 3     return (text_s==word).sum()
#       4
#       5 def get_bad_words_count(text, bad_words):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     370         res_values = comparison_op(lvalues, rvalues, op)
#     371
# --> 372         return self._construct_result(res_values, name=res_name)
#     373
#     374     wrapper.__name__ = op_name
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _construct_result(self, result, name)
#    2755         # We do not pass dtype to ensure that the Series constructor
#    2756         #  does inference in the case where `result` has object-dtype.
# -> 2757         out = self._constructor(result, index=self.index)
#    2758         out = out.__finalize__(self)
#    2759
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     310                 # have a proper length
#     311                 try:
# --> 312                     if len(index) != len(data):
#     313                         raise ValueError(
#     314                             f"Length of passed values is {len(data)}, "
#
# KeyboardInterrupt:

# %%
display(sns.lmplot(col="group", hue="group", data=df,x='bad_words_count',y='score'))
display(sns.lmplot(data=df,x='bad_words_count',y='score'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-c01a439c61b4> in <module>
# ----> 1 display(sns.lmplot(col="group", hue="group", data=df,x='bad_words_count',y='score'))
#       2 display(sns.lmplot(data=df,x='bad_words_count',y='score'))
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     583     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     584     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 585     data = data[cols]
#     586
#     587     # Initialize the grid
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['score'] not in index"

# %% [markdown]
# ## Person correlation

# %%
print('For all data:', scipy.stats.pearsonr(df.bad_words_count,df.score))

for group in df.group.unique():
    print('For {}:'.format(group), scipy.stats.pearsonr(df[df.group==group].bad_words_count, df[df.group==group].score))

# %% [markdown]
# ## Spearman correlation

# %%
print('For all data:', scipy.stats.spearmanr(df.bad_words_count,df.score))

for group in df.group.unique():
    print('For {}:'.format(group), scipy.stats.spearmanr(df[df.group==group].bad_words_count, df[df.group==group].score))

# %% [markdown]
# ### Kruskal-Wallis on bad words count

# %%
result = stats.kruskal(
        df[df.group=='White Man']['bad_words_count'],
        df[df.group=='White Woman']['bad_words_count'],
        df[df.group=='Black Man']['bad_words_count'],
        df[df.group=='Black Woman']['bad_words_count'],
    )
result

# %%
sns.displot(df, x="bad_words_count", hue="group", kind="ecdf",complementary=True) #checar o que sao adjetivos

# %% [markdown]
# ---

# %% [markdown]
# # Words relation - bad words

# %%
bad_words = word_scores[word_scores.score>0.2]

bad_words = bad_words.set_index('words')
bad_words['White Man'] = np.nan
bad_words['Black Man'] = np.nan
bad_words['White Woman'] = np.nan
bad_words['Black Woman'] = np.nan

for bad_word in tqdm(bad_words.index):
    for group in df.group.unique():
        total = 0
        for sent in df[df.group==group].text_clean:
             total += get_word_count(sent,bad_word)
        bad_words.loc[bad_word,group] = total
            
# bad_words = bad_words.reset_index()

# %%
display(bad_words['White Man'].sort_values(ascending=False).head(20))
display(bad_words['White Woman'].sort_values(ascending=False).head(20))
display(bad_words['Black Man'].sort_values(ascending=False).head(20))
display(bad_words['Black Woman'].sort_values(ascending=False).head(20))

# %% [markdown]
# ### Word: dope - Black Man

# %%
before,after = get_word_relations('dope', df[df['group']=="Black Man"].text_clean)

# %%
display(before,after)

# %% [markdown]
# ### Word: damn - Black Woman

# %%
a,b = get_word_relations('damn', df[df['group']=="Black Woman"].text_clean)

# %%
display(a,b)

# %% [markdown]
# ### Word: gay - Black Woman

# %%
a,b = get_word_relations('gay', df[df['group']=="Black Woman"].text_clean)

# %%
display(a,b)

# %% [markdown]
# ### Word: extra

# %%
a,b = get_word_relations('hella', df.text_clean)

# %%
display(a,b)

# %% [markdown]
# ---

# %% [markdown]
# # Words relation - informal - LIWC

# %%
informal = pd.DataFrame()
informal['White Man'] = np.nan
informal['Black Man'] = np.nan
informal['White Woman'] = np.nan
informal['Black Woman'] = np.nan

# %%
for i,data in df.iterrows():
    for word in data.text_clean.split(' '):
        liwc_val = liwc.parse([word])['informal']
        if liwc_val>0:
            if word not in informal.index:
                informal.loc[word,data.group] = liwc_val
            else:
                informal.loc[word,data.group] += liwc_val
informal = informal.fillna(0)

# %%
informal.idxmax()

# %%
#We need to computete each informal word toxicity value to compare who much toxicity is added by this words

# %% [markdown]
# ---

# %% [markdown]
# # Looking for correlations in the data

# %% [markdown]
# ### Top k = 20

# %%
topk = df.sort_values('score',ascending = False).groupby('group').head(20)

# %%
_vars = ['swear','social','informal','netspeak','anx','adj','quant','filler']

for var in _vars:
    topk[var] = topk.liwc_count.apply(get_key_counts,args=(var,))

# %%
sns.pairplot(topk[_vars+['score','group']], hue='group')

# %% [markdown]
# ### Person correlation

# %%
print('For all data:', scipy.stats.spearmanr(topk.bad_words_count,topk.score))

for group in df.group.unique():
    print('For {}:'.format(group), scipy.stats.spearmanr(topk[topk.group==group].bad_words_count, topk[topk.group==group].score))

# %%
bad_words = word_scores[word_scores.score>0.2]

bad_words = bad_words.set_index('words')
bad_words['White Man'] = np.nan
bad_words['Black Man'] = np.nan
bad_words['White Woman'] = np.nan
bad_words['Black Woman'] = np.nan

for bad_word in tqdm(bad_words.index):
    for group in df.group.unique():
        total = 0
        for sent in df[df.group==group].text_clean:
             total += get_word_count(sent,bad_word)
        bad_words.loc[bad_word,group] = total

# %%
data = json.load(open('../data/bad_words_scored.json'))
word_scores = pd.DataFrame({'words':data.keys(),'score': data.values()})
# bad_words = word_scores[word_scores.score>0.2]

# %%
word_scores = []

# %%
l = []
df['has_bad_word'] = False
for word in tqdm(word_scores[word_scores.score>0.8].words):
    df['has_bad_word'] |= df.text_clean.str.contains(word)
    print(word, df.text_clean.str.contains(word).sum())

# %%
df.groupby('group').sum()

# %%
df.groupby('group').count()

# %% [markdown]
# ### Word: gay - Black Woman

# %%
a,b = get_word_relations('gay', df[df['group']=="Black Woman"].text_clean)

# %%
display(a,b)

# %%
display(get_word_relations('ass',topk[topk.group=='Black Woman'].text_clean))
print()
display(get_word_relations('ass',topk[topk.group=='White Man'].text_clean))

# %%
display(get_word_relations('black',topk[topk.group=='Black Woman'].text_clean))
print()
display(get_word_relations('black',topk[topk.group=='White Man'].text_clean))

# %% [markdown]
# ---

# %%
var = 'informal'
topk[var] = topk.liwc_count.apply(get_key_counts,args=(var,))
display(sns.lmplot(col="group", hue="group", data=df,x=var,y='score'))

# %% [markdown]
# ---

# %%
var = 'swear'
topk[var] = topk.liwc_count.apply(get_key_counts,args=(var,))
display(sns.lmplot(col="group", hue="group", data=df,x=var,y='score'))

df[var] = df.liwc_count.apply(get_key_counts,args=(var,))
display(sns.lmplot(col="group", hue="group", data=df,x=var,y='score'))

# %% [markdown]
# ---

# %%
experiments[experiments['pvalue']<0.02].sort_values('pvalue')
